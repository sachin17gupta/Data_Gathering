# %% [markdown]
# # MACHINE LEARNING:(DATA GATHERING.)

# %% [markdown]
# ### FETCHING A DATA FROM AN API:

# %%
import pandas as pd 
import requests

# %% [markdown]
# ### API KEY PASTE

# %%
response =  requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=3c67f46b38ab165a060b882feb907f0a&langage=en-US&page=1')

# %% [markdown]
# ### COLLECTING A WHOLE DATA FROM  AN API:

# %% [markdown]
# ### GET A DATA FROM PAGE 1:

# %%
df = pd.DataFrame(response.json()['results'])

# %% [markdown]
# ### DF SHOWS

# %%
df
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2   False  /b6w7gKLQLS2zw4JK0XmKgQ4gnzr.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 5   False  /m4TUa2ciEWSlk37rOsjiSIvZDXE.jpg   [16, 10751, 14]     129
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 7   False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]     155
# 8   False  /8eihUxjQsJ7WvGySkVMC0EwbPAD.jpg      [35, 53, 18]  496243
# 9   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]     497
# 10  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [16, 10749, 18]  372058
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# ...

# %%
df.shape
# Out:
# (20, 6)

# %% [markdown]
# ### COLLECTING A 6 COLUMNS FROM API:

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']] 
df
# Out:
#         id                                          title release_date  \
# 0      278                       The Shawshank Redemption   1994-09-23
# 1      238                                  The Godfather   1972-03-14
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4      389                                   12 Angry Men   1957-04-10
# 5      129                                  Spirited Away   2001-07-20
# 6    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 7      155                                The Dark Knight   2008-07-16
# 8   496243                                       Parasite   2019-05-30
# 9      497                                 The Green Mile   1999-12-10
# 10  372058                                     Your Name.   2016-08-26
# 11     680                                   Pulp Fiction   1994-09-10
# ...

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  vote_average
# 0  Imprisoned in the 1940s for the double murder ...     166.609         8.700
# 1  Spanning the years 1945 to 1955, a chronicle o...     167.615         8.692
# 2  In the continuing saga of the Corleone crime f...     124.249         8.576
# 3  The true story of how businessman Oskar Schind...     124.504         8.567
# 4  The defense and the prosecution have rested an...     110.113         8.500

# %%
df.tail()
# Out:
#         id                           title release_date  \
# 15     429  The Good, the Bad and the Ugly   1966-12-22
# 16  667257               Impossible Things   2021-06-17
# 17   12477          Grave of the Fireflies   1988-04-16
# 18     346                   Seven Samurai   1954-04-26
# 19     637               Life Is Beautiful   1997-12-20
#
#                                              overview  popularity  \
# 15  While the Civil War rages on between the Union...     115.361
# 16  After the death of her abusive husband, Matild...      15.920
# 17  In the final months of World War II, 14-year-o...       0.075
# 18  A samurai answers a village's request for prot...      58.242
# 19  A touching story of an Italian book seller of ...      64.669
#
#     vote_average
# 15         8.500
# 16         8.459
# 17         8.459
# 18         8.458
# 19         8.451

# %% [markdown]
# ### GET A DATA FROM PAGE 5:

# %%
response =  requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=3c67f46b38ab165a060b882feb907f0a&langage=en-US&page=5')
df1 = pd.DataFrame(response.json()['results'])
df1
# Out:
#     adult                     backdrop_path                genre_ids      id  \
# 0   False  /6rmb35g7XoMCMQtnbH0rUecFZlV.jpg              [18, 10402]   10376
# 1   False  /88J6waYVTta8Qz3iX3qUeWNA5d5.jpg              [18, 10749]  447362
# 2   False  /xGzcusHWxLPvRYSBMeOJOVkdJbj.jpg              [18, 10752]   25237
# 3   False  /1EAxNqdkVnp48a7NUuNBHGflowM.jpg        [16, 28, 878, 18]  283566
# 4   False  /wXsQvli6tWqja51pYxXNG1LFIGV.jpg          [10751, 16, 18]    8587
# 5   False  /nbAbAk80aWCpOS5kOPYJ1L9kE1R.jpg       [10402, 18, 10749]  630566
# 6   False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg            [12, 878, 28]  299534
# 7   False  /sdwjQEM869JFwMytTmvr6ggvaUl.jpg       [18, 53, 9648, 28]     670
# 8   False  /aLqtWLA6NQHBwQHvHDq5z4EKUm0.jpg      [16, 14, 10749, 18]  533514
# 9   False  /mlxKite1x1PgmIhJgAxNS9eHmH8.jpg  [16, 10751, 12, 35, 14]  508965
# 10  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg            [12, 28, 878]  299536
# ...

# %%
df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']] 
df1
# Out:
#         id                                              title release_date  \
# 0    10376                                 The Legend of 1900   1998-10-28
# 1   447362                                     Life in a Year   2020-11-27
# 2    25237                                       Come and See   1985-10-17
# 3   283566             Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08
# 4     8587                                      The Lion King   1994-06-24
# 5   630566                                             Clouds   2020-10-09
# 6   299534                                  Avengers: Endgame   2019-04-24
# 7      670                                             Oldboy   2003-11-21
# 8   533514                       Violet Evergarden: The Movie   2020-09-18
# 9   508965                                              Klaus   2019-11-08
# 10  299536                             Avengers: Infinity War   2018-04-25
# ...

# %%
df1.head()
# Out:
#        id                                   title release_date  \
# 0   10376                      The Legend of 1900   1998-10-28
# 1  447362                          Life in a Year   2020-11-27
# 2   25237                            Come and See   1985-10-17
# 3  283566  Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08
# 4    8587                           The Lion King   1994-06-24
#
#                                             overview  popularity  vote_average
# 0  The story of a virtuoso piano player who lives...      36.253         8.263
# 1  A 17 year old finds out that his girlfriend is...      63.517         8.263
# 2  The invasion of a village in Byelorussia by Ge...      66.961         8.261
# 3  In the aftermath of the Fourth Impact, strande...      82.447         8.258
# 4  A young lion prince is cast out of his pride b...     175.087         8.257

# %%
df1.tail()
# Out:
#         id                                              title release_date  \
# 15  618344                 Justice League Dark: Apokolips War   2020-05-05
# 16  110420                                      Wolf Children   2012-07-21
# 17  572154           Rascal Does Not Dream of a Dreaming Girl   2019-06-15
# 18  504253                        I Want to Eat Your Pancreas   2018-09-01
# 19  635302  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...   2020-10-16
#
#                                              overview  popularity  \
# 15  Earth is decimated after intergalactic tyrant ...      49.177
# 16  After her werewolf lover unexpectedly dies in ...      70.388
# 17  In Fujisawa, Sakuta Azusagawa is in his second...      50.701
# 18  After his classmate and crush is diagnosed wit...      66.718
# 19  Tanjiro Kamado, joined with Inosuke Hashibira,...     204.508
#
#     vote_average
# 15         8.200
# 16         8.233
# 17         8.231
# 18         8.229
# 19         8.226

# %%
df1.shape
# Out:
# (20, 6)

# %% [markdown]
# ### CONVERTING THE API FILE INTO CSV FILE

# %%
df1.to_csv('movies.csv')

# %%
df1
# Out:
#         id                                              title release_date  \
# 0    10376                                 The Legend of 1900   1998-10-28
# 1   447362                                     Life in a Year   2020-11-27
# 2    25237                                       Come and See   1985-10-17
# 3   283566             Evangelion: 3.0+1.0 Thrice Upon a Time   2021-03-08
# 4     8587                                      The Lion King   1994-06-24
# 5   630566                                             Clouds   2020-10-09
# 6   299534                                  Avengers: Endgame   2019-04-24
# 7      670                                             Oldboy   2003-11-21
# 8   533514                       Violet Evergarden: The Movie   2020-09-18
# 9   508965                                              Klaus   2019-11-08
# 10  299536                             Avengers: Infinity War   2018-04-25
# ...

# %%
df.to_csv('movies_page1.csv')
df
# Out:
#         id                                          title release_date  \
# 0      278                       The Shawshank Redemption   1994-09-23
# 1      238                                  The Godfather   1972-03-14
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4      389                                   12 Angry Men   1957-04-10
# 5      129                                  Spirited Away   2001-07-20
# 6    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 7      155                                The Dark Knight   2008-07-16
# 8   496243                                       Parasite   2019-05-30
# 9      497                                 The Green Mile   1999-12-10
# 10  372058                                     Your Name.   2016-08-26
# 11     680                                   Pulp Fiction   1994-09-10
# ...
